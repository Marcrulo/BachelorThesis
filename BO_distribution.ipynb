# %%
import pandas as pd
import os
from matplotlib import pyplot as plt

# %%
csv_path = os.path.abspath(os.path.join(
    os.getcwd(),
    os.pardir,
    'datasets',
    'quality_scores.csv'
))


df = pd.read_csv(csv_path)
df
# Out:
#       Experiment  Index  Param1  Param2  Param3  Param4  Area sum  BLOBs  \
# 0             56      0     2.0      58     2.0     222      2306    NaN
# 1             56      1     2.0      58     2.0     222      2300    NaN
# 2             56      2     2.0      58     2.0     222      2373    NaN
# 3             56      3     2.0      58     2.0     222      2406    NaN
# 4             56      4     2.0      58     2.0     222      3057    NaN
# ...          ...    ...     ...     ...     ...     ...       ...    ...
# 1194         123      5     1.1      60     2.0     220      5375    NaN
# 1195         123      6     1.1      60     2.0     220      4098    NaN
# 1196         123      7     1.1      60     2.0     220      3576    NaN
# 1197         123      8     1.1      60     2.0     220      5783    NaN
# 1198         123      9     1.1      60     2.0     220      4899    NaN
#
#       Area mean  Area std  Roundness mean  Roundness std  Perimeter mean  \
# ...

# %%
filter_df = df.copy()
#filter_df = filter_df[filter_df['Param1']>1.2]
#filter_df = filter_df[filter_df['Area sum']>20000]

fig, axs = plt.subplots(1,4,figsize=(20,5))
for i in range(4):
    axs[i].scatter(filter_df["Param"+str(i+1)], filter_df["Area sum"])
    # axs[i].set_title("Param"+str(i+1))
    axs[i].set_ylim(df['Area sum'].min(), df['Area sum'].max()+500)
axs[0].set_title("Proportion Valve Porex")
axs[1].set_title("Weld Energy")
axs[2].set_title("Weld Pressure")
axs[3].set_title("Triggerforce")

plt.show()
